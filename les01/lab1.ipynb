# %% [markdown]
# # Лабораторная работа №1. Подготовка среды для анализа данных
# #### Студент: Хмелев Вячеслав Дмитриевич
# #### Группа: 12002309

# %% [markdown]
# ## Цель работы:

# %% [markdown]
# 1. Создал учетную запись в сервисе GitHub
# 2. Выполнил форк репозитория https://github.com/chebotarevsa/dap-2024
# 3. Создайл учетную запись в [Google Colab](https://colab.research.google.com)
# 4. Настройл интеграцию Google Colab и GitHub
# 5. Создайл в Google Colab отчет о выполненой работе в виде файла rep.ipynb. Используйте Markdown разметку (заголовки, списки, форматированный текст, ссылки)
# 6. Сохранил отчет в ваш репозиторий github в директории ./les01
# 7. Создал pull request в репозиторий https://github.com/chebotarevsa/dap-2024. Название pull request должно иметь формат "<Номер лабораторной работы>  <Номер группы> <ФИО>"
# 8. Сдал работу в системе "Пегас", в отчет укажите ссылку на pull request

# %% [markdown]
# ## Вопросы

# %% [markdown]
# 1. Типы ячеек в Jupyter Notebook.
#
#  Code — для выполнения Python-кода
#
#  Markdown — для текста, заголовков, списков, формул.
#
#  Raw — необработанный текст, не интерпретируется.
#
# 2. Как с помощью Markdown сформировать иерархический список?
#
#  - Пункт 1
#     - Подпункт 1.1
#     - Подпункт 1.2
# - Пункт 2
#
# 3. Как с помощью Markdown оформить цитату?
#
# > Это цитата
#
# 4. Как в текстовую ячейку вставить отформатированный блок кода?
#
# ```python
# print("Hello, World!")

# %% [markdown]
# 5. Сколько уровней заголовка существует в  Markdown?
#
#  Уровни заголовка в Markdown: до шести
#
# 6. Шаги процесса анализа данных, рассказать подробно про один из шагов (на выбор преподавателя).
# Сбор данных
# Очистка данных
# Исследовательский анализ (EDA)
# Моделирование
# Интерпретация результатов
#
# 7. Типы данных, рассказать подробно про один из типов данных (на выбор преподавателя).
#
# int, float, str, bool, list, tuple, dict, set
# Пример: Список (list) — упорядоченная изменяемая коллекция элементов, может содержать разные типы, поддерживает индексацию и срезы.
#
# 8. Что такое Jupyter Notebook, для чего используется?
#
# Интерактивная среда для написания и выполнения кода, документации и визуализации данных в одном документе. Используется для анализа данных, обучения и презентаций.
#
# 9. Почему python популярен для анализа данных?
#
# Простота синтаксиса, большое количество библиотек (Pandas, NumPy, Matplotlib, Scikit-learn), активное сообщество, интеграция с инструментами визуализации.
#
# 10. Обязательно ли использовать Jupyter Notebook для анализа данных?
#
# Нет, можно использовать любые IDE или скрипты Python, но Jupyter удобен для интерактивного анализа, документации и визуализации.
